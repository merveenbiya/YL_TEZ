# %% [markdown]
# <a href="https://colab.research.google.com/github/merveenbiya/YL_TEZ/blob/main/feature_importance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Fiili Geçiş - Öğle - Öğrenci

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_fiiligecis_ogle_ogrenci.csv')

etiket = data['fiili_gecis_ogrenci_ogle']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('fiili_gecis_ogrenci_ogle', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Fiili Geçiş - Öğle - Öğrenci (Feature Importance)')
plt.show()
# Out:
#                        Feature  Importance
# 5             haftanin_günleri    0.339792
# 1                    ana_yemek    0.151608
# 12        anlik_hava_sicakligi    0.119748
# 11         beklenen_hava_olayi    0.089552
# 10     beklenen_hava_sicakligi    0.065401
# 3                      ek_gida    0.064671
# 2                    ara_yemek    0.045951
# 8                toplam_kalori    0.040495
# 13            anlik_hava_olayi    0.028421
# 0                        corba    0.025519
# 16       aylik_enflasyon_orani    0.009135
# 14  ogrenci_kyk_odenme_takvimi    0.009114
# 6                    yilin_ayi    0.005448
# 15      yillik_enflasyon_orani    0.005144
# 9                       mevsim    0.000000
# 7                   dst_donemi    0.000000
# 4                  ramazan_ayi    0.000000
# <ipython-input-20-201cb1180c35>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Fiili Geçiş - Akşam - Öğrenci

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_fiiligecis_aksam_ogrenci.csv')

etiket = data['fiili_gecis_ogrenci_aksam']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('fiili_gecis_ogrenci_aksam', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Fiili Geçiş - Akşam - Öğrenci (Feature Importance)')
plt.show()
# Out:
#                        Feature  Importance
# 12        anlik_hava_sicakligi    0.273384
# 10     beklenen_hava_sicakligi    0.106876
# 5             haftanin_günleri    0.104694
# 1                    ana_yemek    0.103173
# 3                      ek_gida    0.094992
# 13            anlik_hava_olayi    0.051659
# 2                    ara_yemek    0.050653
# 8                toplam_kalori    0.050143
# 6                    yilin_ayi    0.036456
# 15      yillik_enflasyon_orani    0.035052
# 16       aylik_enflasyon_orani    0.034735
# 0                        corba    0.025438
# 11         beklenen_hava_olayi    0.024954
# 14  ogrenci_kyk_odenme_takvimi    0.007792
# 9                       mevsim    0.000000
# 7                   dst_donemi    0.000000
# 4                  ramazan_ayi    0.000000
# <ipython-input-21-598ba50c77c9>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Fiili Geçiş - Toplam - Öğrenci

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_fiiligecis_toplam_ogrenci.csv')

etiket = data['fiili_ogrenci_toplam_gecis_sayisi']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('fiili_ogrenci_toplam_gecis_sayisi', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Fiili Geçiş - Toplam - Öğrenci (Feature Importance)')
plt.show()
# Out:
#                        Feature  Importance
# 5             haftanin_günleri    0.327054
# 12        anlik_hava_sicakligi    0.159632
# 1                    ana_yemek    0.130887
# 10     beklenen_hava_sicakligi    0.072213
# 3                      ek_gida    0.064622
# 11         beklenen_hava_olayi    0.045793
# 2                    ara_yemek    0.042868
# 13            anlik_hava_olayi    0.037237
# 8                toplam_kalori    0.035423
# 0                        corba    0.031287
# 16       aylik_enflasyon_orani    0.018931
# 6                    yilin_ayi    0.014749
# 15      yillik_enflasyon_orani    0.013435
# 14  ogrenci_kyk_odenme_takvimi    0.005870
# 9                       mevsim    0.000000
# 7                   dst_donemi    0.000000
# 4                  ramazan_ayi    0.000000
# <ipython-input-22-40193f018ba6>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Satış - Öğle - Öğrenci

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_satis_ogle_ogrenci.csv')

etiket = data['satis_ogrenci_ogle']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('satis_ogrenci_ogle', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Satış - Öğle - Öğrenci (Feature Importance)')
plt.show()
# Out:
#                        Feature  Importance
# 5             haftanin_günleri    0.299644
# 1                    ana_yemek    0.169097
# 12        anlik_hava_sicakligi    0.104809
# 10     beklenen_hava_sicakligi    0.089673
# 11         beklenen_hava_olayi    0.077296
# 3                      ek_gida    0.075973
# 13            anlik_hava_olayi    0.038083
# 0                        corba    0.037055
# 8                toplam_kalori    0.035879
# 2                    ara_yemek    0.029525
# 16       aylik_enflasyon_orani    0.012630
# 6                    yilin_ayi    0.012184
# 15      yillik_enflasyon_orani    0.011273
# 14  ogrenci_kyk_odenme_takvimi    0.006879
# 9                       mevsim    0.000000
# 7                   dst_donemi    0.000000
# 4                  ramazan_ayi    0.000000
# <ipython-input-23-25f5e8e679c7>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Satış - Akşam - Öğrenci

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_satis_aksam_ogrenci.csv')

etiket = data['satis_ogrenci_aksam']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('satis_ogrenci_aksam', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Satış - Akşam - Öğrenci (Feature Importance)')
plt.show()
# Out:
#                        Feature  Importance
# 12        anlik_hava_sicakligi    0.270324
# 10     beklenen_hava_sicakligi    0.236248
# 3                      ek_gida    0.103540
# 1                    ana_yemek    0.073363
# 2                    ara_yemek    0.053565
# 8                toplam_kalori    0.052454
# 13            anlik_hava_olayi    0.052436
# 6                    yilin_ayi    0.042107
# 16       aylik_enflasyon_orani    0.033241
# 0                        corba    0.024646
# 15      yillik_enflasyon_orani    0.023531
# 5             haftanin_günleri    0.021545
# 11         beklenen_hava_olayi    0.008341
# 14  ogrenci_kyk_odenme_takvimi    0.004658
# 9                       mevsim    0.000000
# 7                   dst_donemi    0.000000
# 4                  ramazan_ayi    0.000000
# <ipython-input-24-0cbed7e91dea>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Satış - Toplam - Öğrenci

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_satis_toplam_ogrenci.csv')

etiket = data['satis_ogrenci_toplam']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('satis_ogrenci_toplam', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Satış - Toplam - Öğrenci (Feature Importance)')
plt.show()
# Out:
#                        Feature  Importance
# 5             haftanin_günleri    0.203762
# 12        anlik_hava_sicakligi    0.178226
# 1                    ana_yemek    0.144880
# 3                      ek_gida    0.096869
# 10     beklenen_hava_sicakligi    0.093247
# 11         beklenen_hava_olayi    0.052278
# 8                toplam_kalori    0.052122
# 13            anlik_hava_olayi    0.040324
# 0                        corba    0.037713
# 2                    ara_yemek    0.032855
# 16       aylik_enflasyon_orani    0.021637
# 15      yillik_enflasyon_orani    0.020422
# 6                    yilin_ayi    0.019671
# 14  ogrenci_kyk_odenme_takvimi    0.005992
# 9                       mevsim    0.000000
# 7                   dst_donemi    0.000000
# 4                  ramazan_ayi    0.000000
# <ipython-input-25-7ef0f4988b9e>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Fiili Geçiş - Öğle - Personel

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_fiiligecis_ogle_personel.csv')

etiket = data['fiili_gecis_personel_ogle']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('fiili_gecis_personel_ogle', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Fiili Geçiş - Öğle - Personel (Feature Importance)')
plt.show()
# Out:
#                          Feature  Importance
# 1                      ana_yemek    0.323465
# 5               haftanin_günleri    0.239395
# 10       beklenen_hava_sicakligi    0.088392
# 8                  toplam_kalori    0.076103
# 12          anlik_hava_sicakligi    0.055728
# 3                        ek_gida    0.054150
# 2                      ara_yemek    0.049728
# 0                          corba    0.043816
# 13              anlik_hava_olayi    0.030273
# 11           beklenen_hava_olayi    0.017101
# 15        yillik_enflasyon_orani    0.006171
# 16         aylik_enflasyon_orani    0.005935
# 6                      yilin_ayi    0.005492
# 14  personel_maas_odenme_takvimi    0.004252
# 7                     dst_donemi    0.000000
# 9                         mevsim    0.000000
# 4                    ramazan_ayi    0.000000
# <ipython-input-26-edeaad2b019c>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')

# %% [markdown]
# # Satış - Öğle - Personel

# %%
data = pd.read_csv('/content/drive/MyDrive/Merve Enbiyaoğlu Tez/data/data_satis_ogle_personel.csv')

etiket = data['satis_personel_ogle']

# Kategorik sütunları sayısal formata
label_encoder = LabelEncoder()
data['corba'] = label_encoder.fit_transform(data['corba'])
data['ana_yemek'] = label_encoder.fit_transform(data['ana_yemek'])
data['ara_yemek'] = label_encoder.fit_transform(data['ara_yemek'])
data['ek_gida'] = label_encoder.fit_transform(data['ek_gida'])
data['haftanin_günleri'] = label_encoder.fit_transform(data['haftanin_günleri'])
data['dst_donemi'] = label_encoder.fit_transform(data['dst_donemi'])
data['mevsim'] = label_encoder.fit_transform(data['mevsim'])
data['beklenen_hava_olayi'] = label_encoder.fit_transform(data['beklenen_hava_olayi'])
data['anlik_hava_olayi'] = label_encoder.fit_transform(data['anlik_hava_olayi'])

#print(data)


data = data.drop('satis_personel_ogle', axis=1)

model = RandomForestRegressor()

model.fit(data, etiket)

feature_importance = model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Satış - Öğle - Personel (Feature Importance)')
plt.show()
# Out:
#                          Feature  Importance
# 1                      ana_yemek    0.299015
# 5               haftanin_günleri    0.204817
# 12          anlik_hava_sicakligi    0.089888
# 10       beklenen_hava_sicakligi    0.085524
# 8                  toplam_kalori    0.071803
# 3                        ek_gida    0.068606
# 0                          corba    0.044632
# 2                      ara_yemek    0.042713
# 11           beklenen_hava_olayi    0.029159
# 13              anlik_hava_olayi    0.026719
# 6                      yilin_ayi    0.015036
# 15        yillik_enflasyon_orani    0.010122
# 16         aylik_enflasyon_orani    0.007963
# 14  personel_maas_odenme_takvimi    0.004002
# 7                     dst_donemi    0.000000
# 9                         mevsim    0.000000
# 4                    ramazan_ayi    0.000000
# <ipython-input-27-0690306ff83f>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
